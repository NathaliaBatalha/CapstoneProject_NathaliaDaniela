# %% [markdown]
# ## **INFO from web:**

# %% [markdown]
# Veure l'estat de les estacions al dataset Estat de les estacions del nou Bicing de la ciutat de Barcelona
# Observacions:
# Degut a:
# Incidències tècniques:
# - L'històric del més de juny'19 no disposa de dades del dia 20 entre les 7:40h i les 14:00h.
# - L'històric del mes de juliol'19 no disposa de dades des del dia 26 a les 13:30h fins el dia 29 a les 10:40h.
# - L'històric del mes de novembre'19 pot no disposar d'algunes dades de les 22:00h del 26/11 fins a les 11:00h del dia 27/11.
# - L'històric del mes d'agost'20 no disposa de dades des del dia 7 a les 2:25h fins el dia 10 a les 10:40h.
# - L'històric del mes de novembre'20 no disposa de dades els següents dies/hores:
# dia 04 de la 01:45 a les 11:05h
# dia 20 de les 19:50h al dia 21 a les 10:50h
# dia 27 de les 02:50h al 30 a les 09:50h
#
# Altres:
# - Amb motiu de les mesures del Covid-19 el servei de Bicing s'ha aturat temporalment i l'històric de març reflexa aquesta situació
#
# **Data Dictionary**
#
# - *last_updated*: Timestamp de les dades mostrades
# - *ttl*: TTL de la resposta
# - *data*: Array de dades d'informació
# - *stations*: Array de dades de les estacions
# - *station_id*: Identificador de l'estació
# - *name*: Nom de l'estació
# - *physical_configuration*: Tipus d'estació (MECHANICBIKESTATION=Estació de bicicletes mecàniques,
# ELECTRICBIKESTATION=Estació de bicicletes mecàniques i elèctriques)
# - *lat*: Latitut de l'estació
# - *lon*: Longitut de l'estació
# - *altitude*: Cota d'altitut de l'estació
# - *address*: Adreça postal de l'estació
# - *post_code*: Codi postal de l'estació
# - *capacity*: Capacitat de l'estació

# %% [markdown]
# ## Required libraries:

# %%
import os
import json
import urllib
import pandas as pd
import numpy as np
from pandas import Timestamp, Series, date_range
from datetime import datetime
import lzma

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install

# %%
# !apt-get install p7zip-full p7zip-rar
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-7build1).
# The following NEW packages will be installed:
#   p7zip-rar
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 44.8 kB of archives.
# After this operation, 118 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/multiverse amd64 p7zip-rar amd64 16.02-3build1 [44.8 kB]
# Fetched 44.8 kB in 0s (159 kB/s)
# Selecting previously unselected package p7zip-rar.
# (Reading database ... 122541 files and directories currently installed.)
# Preparing to unpack .../p7zip-rar_16.02-3build1_amd64.deb ...
# Unpacking p7zip-rar (16.02-3build1) ...
# Setting up p7zip-rar (16.02-3build1) ...

# %% [markdown]
# # **DF1: Stations info**
# Unique data frame for all months and years

# %%
#get recent stations info from website
df_json = pd.read_json('https://opendata-ajuntament.barcelona.cat/data/dataset/bd2462df-6e1e-4e37-8205-a4b8e7313b84/resource/e5adca8d-98bf-42c3-9b9c-364ef0a80494/download')

# %%
#select dictionary
data_station_info = df_json['data']['stations']
df_station_info = pd.DataFrame.from_dict(data_station_info)

# %%
df_station_info
# Out:
#      station_id                                 name physical_configuration  \
# 0             1        GRAN VIA CORTS CATALANES, 760    ELECTRICBIKESTATION
# 1             2                C/ ROGER DE FLOR, 126    ELECTRICBIKESTATION
# 2             3                        C/ NÀPOLS, 82    ELECTRICBIKESTATION
# 3             4                         C/ RIBES, 13    ELECTRICBIKESTATION
# 4             5  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)    ELECTRICBIKESTATION
# ..          ...                                  ...                    ...
# 501         515                    C/ SANT ADRIÀ, 43    ELECTRICBIKESTATION
# 502         516                    C/ SANT ADRIÀ, 88    ELECTRICBIKESTATION
# 503         517             AV. RASOS DE PEGUERA, 10    ELECTRICBIKESTATION
# 504         518                    C/ LLOBREGÓS, 115    ELECTRICBIKESTATION
# 505         519                       C/ PEDRELL, 52    ELECTRICBIKESTATION
#
#            lat       lon  altitude                              address  \
# 0    41.397978  2.180107      16.0        GRAN VIA CORTS CATALANES, 760
# 1    41.395488  2.177198      17.0                C/ ROGER DE FLOR, 126
# 2    41.394156  2.181331      11.0                        C/ NÀPOLS, 82
# 3    41.393317  2.181248       8.0                         C/ RIBES, 13
# 4    41.391103  2.180176       7.0  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)
# ..         ...       ...       ...                                  ...
# 501  41.435207  2.194800      19.0                    C/ SANT ADRIÀ, 43
# 502  41.435460  2.200157      15.0                    C/ SANT ADRIÀ, 88
# 503  41.462095  2.178959      44.0             AV. RASOS DE PEGUERA, 10
# 504  41.424689  2.157049     112.0                    C/ LLOBREGÓS, 115
# 505  41.424655  2.166289     110.0                       C/ PEDRELL, 52
#
#     post_code  capacity  is_charging_station  nearby_distance  \
# 0       08013        46                 True           1000.0
# 1       08013        29                 True           1000.0
# 2       08013        27                 True           1000.0
# 3       08013        21                 True           1000.0
# 4       08018        39                 True           1000.0
# ..        ...       ...                  ...              ...
# 501     08030        24                 True           1000.0
# 502     08030        21                 True           1000.0
# 503     08033        20                 True           1000.0
# 504     08032        25                 True           1000.0
# 505     08032        24                 True           1000.0
#
#      _ride_code_support rental_uris cross_street
# 0                  True        None          NaN
# 1                  True        None          NaN
# 2                  True        None          NaN
# 3                  True        None          NaN
# 4                  True        None          NaN
# ..                  ...         ...          ...
# 501                True        None          NaN
# 502                True        None          NaN
# 503                True        None          NaN
# 504                True        None          NaN
# 505                True        None          NaN
#
# [506 rows x 14 columns]

# %%
#check all columns
df_station_info.columns
# Out:
# Index(['station_id', 'name', 'physical_configuration', 'lat', 'lon',
#        'altitude', 'address', 'post_code', 'capacity', 'is_charging_station',
#        'nearby_distance', '_ride_code_support', 'rental_uris', 'cross_street'],
#       dtype='object')

# %%
#select columns of interest 
station_columns = ['station_id', 'name', 'lat', 'lon', 'altitude', 'address', 'post_code', 'capacity']
df_station_reduced = df_station_info.filter(station_columns, axis= 1)

# %%
df_station_reduced.head()
# Out:
#    station_id                                 name        lat       lon  \
# 0           1        GRAN VIA CORTS CATALANES, 760  41.397978  2.180107
# 1           2                C/ ROGER DE FLOR, 126  41.395488  2.177198
# 2           3                        C/ NÀPOLS, 82  41.394156  2.181331
# 3           4                         C/ RIBES, 13  41.393317  2.181248
# 4           5  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)  41.391103  2.180176
#
#    altitude                              address post_code  capacity
# 0      16.0        GRAN VIA CORTS CATALANES, 760     08013        46
# 1      17.0                C/ ROGER DE FLOR, 126     08013        29
# 2      11.0                        C/ NÀPOLS, 82     08013        27
# 3       8.0                         C/ RIBES, 13     08013        21
# 4       7.0  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)     08018        39

# %%
#should we keep address or name columnm? 
df_station_reduced['name'].equals(df_station_reduced['address'])
# Out:
# False

# %%
#differencies are basically formatting
df_name_address = df_station_reduced.query('name != address')
df_name_address
# Out:
#      station_id                                      name        lat  \
# 5             6       PG. LLUIS COMPANYS, 18 (ARC TRIOMF)  41.391429
# 35           37  PL. ANTONIO LÓPEZ (CORREUS, VIA LAIETANA  41.381316
# 75           79                          PL.  UNIVERSITAT  41.385503
# 90           96     GRAN VIA DE LES CORTS CATALANES,  368  41.374109
# 95          101                        AV. DIAGONAL,  602  41.392878
# 98          104                         C/ VALÈNCIA,  621  41.410801
# 106         112                     C/ FLORIDABLANCA,  49  41.377672
# 107         113                    RONDA DE SANT PAU , 51  41.377311
# 110         116      C/ DEL DR. AIGUADER, 72 / PG. SALVAT  41.383837
# 121         127           C/ ARAGÓ, 659 / NAVAS DE TOLOSA  41.412068
# 124         130      RAMBLA DE GUIPÚSCOA, 103 / CANTÀBRIA  41.420014
# 126         132                      PL. VALENTÍ ALMIRALL  41.408480
# 127         133     GRAN VIA DE LES CORTS CATALANES,  902  41.407501
# 131         137    GRAN VIA DE LES CORTS CATALANES , 1041  41.414580
# 132         138    GRAN VIA DE LES CORTS CATALANES,  1118  41.416793
# 134         140                        C/ VILADOMAT,  122  41.380877
# 219         229   C/ DE LA SANTACREU, 2 (PL.DE LA VIRREIN  41.405097
# 253         264   C/REPÚBLICA DOMINICANA,25(CENTRE COMERC  41.439929
# 259         270       CRTA. DE RIBES, 77 (TRINITAT VELLA)  41.448633
# 265         276   PLAÇA ALFONS X EL SAVI / RONDA DEL GUIN  41.412135
# 332         343   CAMPANA DE LA MAQUINISTA (SAO PAULO I P  41.438961
# 334         345   PL. TERESA DE CLARAMUNT/C/ DELS FERROCA  41.363107
# 337         348   JARDINS DE CAN FERRERO/PG.DE LA ZONA FR  41.357067
# 341         352    C/RADI,10/GRAN VIA DE LES CORTS CATALA  41.363279
# 386         397   AV. LITORAL (PG MARÍTIM DEL PORT OLÍMPI  41.388913
# 387         398   PG. MARÍTIM DE LA BARCELONETA/ANDREA DÒ  41.380955
# 482         496                         C/ PROVENÇA,  445  41.404862
#
#           lon  altitude                                         address  \
# 5    2.180569      10.0            PG. LLUIS COMPANYS, 18  (ARC TRIOMF)
# 35   2.181903       4.0       PL. ANTONIO LÓPEZ (CORREUS, VIA LAIETANA)
# 75   2.163477      21.0                                 PL. UNIVERSITAT
# 90   2.148199      24.0            GRAN VIA DE LES CORTS CATALANES, 368
# 95   2.143411      53.0                               AV. DIAGONAL, 602
# 98   2.187244      16.0                                C/ VALÈNCIA, 621
# 106  2.157233      13.0                            C/ FLORIDABLANCA, 49
# 107  2.164674      11.0                           RONDA DE SANT PAU, 51
# 110  2.191476       5.0  C/ DEL DR. AIGUADER, 72 / PG. SALVAT PAPASSEIT
# 121  2.190752      16.0                  C/ ARAGÓ, 659 /NAVAS DE TOLOSA
# 124  2.201670       8.0             RAMBLA DE GUIPÚSCOA, 103 /CANTÀBRIA
# 126  2.192042       6.0                             PL.VALENTÍ ALMIRALL
# 127  2.193017       6.0            GRAN VIA DE LES CORTS CATALANES, 902
# 131  2.200814       7.0           GRAN VIA DE LES CORTS CATALANES, 1041
# 132  2.205834       7.0           GRAN VIA DE LES CORTS CATALANES, 1118
# 134  2.155994      19.0                               C/ VILADOMAT, 122
# 219  2.156916      68.0       C/ DE LA SANTACREU, 2 (PL.DE LA VIRREINA)
# 253  2.197069      20.0     C/REPÚBLICA DOMINICANA,25(CENTRE COMERCIAL)
# 259  2.189837      35.0       270 - CRTA. DE RIBES, 77 (TRINITAT VELLA)
# 265  2.165222      88.0     PLAÇA ALFONS X EL SAVI / RONDA DEL GUINARDO
# 332  2.199618      14.0    CAMPANA DE LA MAQUINISTA (SAO PAULO I PL. DE
# 334  2.139832      10.0     PL. TERESA DE CLARAMUNT/C/ DELS FERROCARILS
# 337  2.141563       7.0     JARDINS DE CAN FERRERO/PG.DE LA ZONA FRANCA
# 341  2.134159       9.0       C/RADI,10/GRAN VIA DE LES CORTS CATALANES
# 386  2.199311       6.0       AV. LITORAL (PG MARÍTIM DEL PORT OLÍMPIC)
# 387  2.193464       4.0      PG. MARÍTIM DE LA BARCELONETA/ANDREA DÒRIA
# 482  2.174799      33.0                                C/ PROVENÇA, 445
#
#     post_code  capacity
# 5       08018        39
# 35      08002        24
# 75      08007        24
# 90      08010        21
# 95      08021        24
# 98      08026        26
# 106     08015        20
# 107     08015        34
# 110     08003        27
# 121     08026        27
# 124     08020        24
# 126     08018        27
# 127     08018        16
# 131     08020        25
# 132     08020        21
# 134     08015        27
# 219     08024        28
# 253     08030        33
# 259     08033        27
# 265     08024        27
# 332     08030        27
# 334     08038        30
# 337     08038        32
# 341     08038        28
# 386     08005        27
# 387     08003        34
# 482     08025        18

# %%
#we decided to keep the "address" column only
df_station_reduced = df_station_reduced.drop(columns=['name'])
df_station_reduced.head()
# Out:
#    station_id        lat       lon  altitude  \
# 0           1  41.397978  2.180107      16.0
# 1           2  41.395488  2.177198      17.0
# 2           3  41.394156  2.181331      11.0
# 3           4  41.393317  2.181248       8.0
# 4           5  41.391103  2.180176       7.0
#
#                                address post_code  capacity
# 0        GRAN VIA CORTS CATALANES, 760     08013        46
# 1                C/ ROGER DE FLOR, 126     08013        29
# 2                        C/ NÀPOLS, 82     08013        27
# 3                         C/ RIBES, 13     08013        21
# 4  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)     08018        39

# %%
df_station_reduced['station_id'].nunique()
# Out:
# 506

# %%
df_station_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   station_id  506 non-null    int64
#  1   lat         506 non-null    float64
#  2   lon         506 non-null    float64
#  3   altitude    506 non-null    float64
#  4   address     506 non-null    object
#  5   post_code   506 non-null    object
#  6   capacity    506 non-null    int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 27.8+ KB

# %%
#post code 8001 should be replaced for 08001
df_station_reduced['post_code'].unique()
# Out:
# array(['08013', '08018', '08003', '08040', '08005', '08009', '08025',
#        '08010', '08037', '08930', '08002', '08039', '08004', '08001',
#        '08007', '08029', '08008', '08011', '08036', '08015', '08014',
#        '08021', '08026', '08024', '08006', '08020', '08019', '08038',
#        '08028', '08034', '08017', '08012', '08027', '08041', '08030',
#        '08033', '08016', '08031', '08032', '08042', '08022', 8001,
#        '08035', '08023'], dtype=object)

# %%
print(df_station_reduced['post_code'].value_counts()['08001'])
print(df_station_reduced['post_code'].value_counts()[8001])
# Out:
# 12
# 1

# %%
#complete with left 0
df_station_reduced['post_code'] = df_station_reduced['post_code'].astype(str).str.zfill(5)

# %%
df_station_reduced['post_code'].unique()
# Out:
# array(['08013', '08018', '08003', '08040', '08005', '08009', '08025',
#        '08010', '08037', '08930', '08002', '08039', '08004', '08001',
#        '08007', '08029', '08008', '08011', '08036', '08015', '08014',
#        '08021', '08026', '08024', '08006', '08020', '08019', '08038',
#        '08028', '08034', '08017', '08012', '08027', '08041', '08030',
#        '08033', '08016', '08031', '08032', '08042', '08022', '08035',
#        '08023'], dtype=object)

# %% [markdown]
# # **DF2: Bicing status info**
# Join all data from web: 2019-2022

# %%
i2m = list(zip(range(1,13), ['Gener','Febrer','Marc','Abril','Maig','Juny','Juliol','Agost','Setembre','Octubre','Novembre','Desembre']))
for year in [2022, 2021, 2020, 2019]:
    for month, month_name in i2m:        
        os.system(f"wget 'https://opendata-ajuntament.barcelona.cat/resources/bcn/BicingBCN/{year}_{month:02d}_{month_name}_BicingNou_ESTACIONS.7z'")
        os.system(f"7z x '{year}_{month:02d}_{month_name}_BicingNou_ESTACIONS.7z'")
        os.system(f"rm '{year}_{month:02d}_{month_name}_BicingNou_ESTACIONS.7z'")

# %%
#rename file, unique with Marc instead of Març 
old_name = r"2020_03_Marc_BicingNou_ESTACIONS.csv"
new_name = r"2020_03_Març_BicingNou_ESTACIONS.csv"
os.rename(old_name, new_name)

# %%
#rename more files of 2019, cause they save as STAT:
old_2019_03_name = r"2019_03_Març_BICING2_STAT.csv"
new_2019_03_name = r"2019_03_Març_BicingNou_ESTACIONS.csv"
os.rename(old_2019_03_name, new_2019_03_name)

old_2019_04_name = r"2019_04_Abril_BICING2_STAT.csv"
new_2019_04_name = r"2019_04_Abril_BicingNou_ESTACIONS.csv"
os.rename(old_2019_04_name, new_2019_04_name)

old_2019_05_name = r"2019_05_Maig_BICING2_STAT.csv"
new_2019_05_name = r"2019_05_Maig_BicingNou_ESTACIONS.csv"
os.rename(old_2019_05_name, new_2019_05_name)

old_2019_06_name = r"2019_06_Juny_NouBicing_ESTACIONS.csv"
new_2019_06_name = r"2019_06_Juny_BicingNou_ESTACIONS.csv"
os.rename(old_2019_06_name, new_2019_06_name)

# %% [markdown]
# ## Functions

# %%
def date_time_columns(df, month, year):
  """
  Function that transforms timestamp to Date/Time 
  and creates new columns for Year, Month, Day, Day of Week, Hour 
  """
  # creates new column with Date/Time, delete Timestamp column and rename
  df['last_reported_2'] = pd.to_datetime(df['last_reported'], unit='s')
  df = df.drop(['last_reported'], axis=1)
  df.rename(columns={"last_reported_2": "last_reported"}, inplace=True)

  #create new columns
  df['date'] = pd.DatetimeIndex(df['last_reported']).date
  df['year'] = pd.DatetimeIndex(df['last_reported']).year
  df['month'] = pd.DatetimeIndex(df['last_reported']).month
  df['day'] = pd.DatetimeIndex(df['last_reported']).day
  df['day_of_week'] = pd.DatetimeIndex(df['last_reported']).dayofweek
  df['hour'] = pd.DatetimeIndex(df['last_reported']).hour

  df = df[(df['year'] == year) & (df['month'] == month)]

  return df

# %%
def dock_availability_normalized(df, columns_groupby):
  """
  Function that creates column for percentage of dock availability 
  and group dates by available mean
  """
  # creates column 'perc_available'
  df['perc_available'] = (df['num_docks_available']/df['capacity'])
  df = df[(df['perc_available'] >= 0) & (df['perc_available'] <= 1)]

  #group by mean
  df_gb = df.groupby(columns_groupby, as_index=False)['perc_available'].mean()
  df_gb['perc_available'] = df_gb['perc_available'].round(2)
  return df_gb

# %%
def check_month(df, month):
  """
  Function that checks if month data is accurate,
  reset index and sort values
  """
  df_clean = df[df.month == month]
  df_clean.reset_index(drop=True)

  #sort by hour
  df_clean.sort_values(by=['station_id', 'month', 'day', 'hour'], inplace=True)

  return df_clean

# %%
def contexts_5h(df):
    """
    Function that creates contexts for every 5h 
    """
    df_context = df.iloc[4::5, :].reset_index(drop=True)

    df_context['ctx-4'] = df['perc_available'].iloc[0::5].reset_index(drop=True)
    df_context['ctx-3'] = df['perc_available'].iloc[1::5].reset_index(drop=True)
    df_context['ctx-2'] = df['perc_available'].iloc[2::5].reset_index(drop=True)
    df_context['ctx-1'] = df['perc_available'].iloc[3::5].reset_index(drop=True)

    return df_context

# %%
def df_month(df):
  """ 
  Function that removes NAN values
  """
  df = df.dropna()
  df = df.reset_index(drop=True)

  return df

# %%
#disable warning
pd.options.mode.copy_on_write = True

# %% [markdown]
# ## Preparing and creating complete data frame:
# For each month and year from web with station information:

# %%
#rewrite months cause it saves Març from web
i2m = list(zip(range(1,13), ['Gener','Febrer','Març','Abril','Maig','Juny','Juliol','Agost','Setembre','Octubre','Novembre','Desembre']))

#variables has the columns of interest **can be changed later**
variables = ['station_id','num_docks_available','status','last_reported']

#create a final DF to be used in the model
df_final = pd.DataFrame()

# Loop over all months and years
for year in [2022, 2021, 2020, 2019]:

    if year==2019:
      #remove cause 2019 has no data for months: 01 and 02
      i2m = i2m[2:]

    for month, month_name in i2m:   

        print(f"{year}_{month:02d}_{month_name}_BicingNou_ESTACIONS.csv")

        print('Preparing data frame...')

        df_read_csv = pd.read_csv(f"{year}_{month:02d}_{month_name}_BicingNou_ESTACIONS.csv")

        #get reduced status data frame
        df_bicing_reduced = df_read_csv.filter(variables, axis=1)
        df_bicing_reduced = df_bicing_reduced[df_bicing_reduced.status == 'IN_SERVICE']

        #merge bicing DF with station info DF
        df_merged = pd.merge(df_bicing_reduced, df_station_reduced, on='station_id', how='inner')

        #date time transformation and new columns
        df_merged = date_time_columns(df_merged, month=month, year=year)

        #compute dock availabity and groups DF
        columns_to_keep = ['station_id', 'lat', 'lon', 'altitude', 'address', 'post_code', 'capacity', 'date', 'year', 
                          'month', 'day', 'day_of_week', 'hour']
        df_grouped = dock_availability_normalized(df_merged, columns_groupby=columns_to_keep)

        #check if has only current month on data set and sort by hour
        df_clean = check_month(df_grouped, month)

        #create contexts
        df_contexts = contexts_5h(df_clean) 

        #get df of current month
        df_sample = df_month(df_contexts)

        print('Data frame of ' + str(year) + ' in month ' + str(month) + ' was created')

        #append to final df and create complete DF
        df_final = pd.concat([df_final, df_sample])

        print('Data frame appended to final df')

        print('------------------------------------------------------------------------------------')
# Out:
# 2022_01_Gener_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2022 in month 1 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2022_02_Febrer_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2022 in month 2 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2022_03_Març_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2022 in month 3 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2022_04_Abril_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2022 in month 4 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2022_05_Maig_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2022 in month 5 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2022_06_Juny_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2022 in month 6 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2022_07_Juliol_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2022 in month 7 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2022_08_Agost_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2022 in month 8 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2022_09_Setembre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2022 in month 9 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2022_10_Octubre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2022 in month 10 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2022_11_Novembre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2022 in month 11 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2022_12_Desembre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2022 in month 12 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2021_01_Gener_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2021 in month 1 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2021_02_Febrer_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2021 in month 2 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2021_03_Març_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2021 in month 3 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2021_04_Abril_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2021 in month 4 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2021_05_Maig_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2021 in month 5 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2021_06_Juny_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2021 in month 6 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2021_07_Juliol_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2021 in month 7 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2021_08_Agost_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2021 in month 8 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2021_09_Setembre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2021 in month 9 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2021_10_Octubre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2021 in month 10 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2021_11_Novembre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2021 in month 11 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2021_12_Desembre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2021 in month 12 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2020_01_Gener_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2020 in month 1 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2020_02_Febrer_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2020 in month 2 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2020_03_Març_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2020 in month 3 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2020_04_Abril_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2020 in month 4 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2020_05_Maig_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2020 in month 5 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2020_06_Juny_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2020 in month 6 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2020_07_Juliol_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2020 in month 7 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2020_08_Agost_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2020 in month 8 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2020_09_Setembre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2020 in month 9 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2020_10_Octubre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2020 in month 10 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2020_11_Novembre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2020 in month 11 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2020_12_Desembre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2020 in month 12 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2019_03_Març_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2019 in month 3 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2019_04_Abril_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2019 in month 4 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2019_05_Maig_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2019 in month 5 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2019_06_Juny_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2019 in month 6 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2019_07_Juliol_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2019 in month 7 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2019_08_Agost_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2019 in month 8 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2019_09_Setembre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2019 in month 9 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2019_10_Octubre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2019 in month 10 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2019_11_Novembre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2019 in month 11 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------
# 2019_12_Desembre_BicingNou_ESTACIONS.csv
# Preparing data frame...
# Data frame of 2019 in month 12 was created
# Data frame appended to final df
# ------------------------------------------------------------------------------------

# %%
df_final.shape
# Out:
# (2952330, 18)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2952330 entries, 0 to 58892
# Data columns (total 18 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   station_id      int64
#  1   lat             float64
#  2   lon             float64
#  3   altitude        float64
#  4   address         object
#  5   post_code       object
#  6   capacity        int64
#  7   date            object
#  8   year            float64
#  9   month           float64
#  10  day             float64
#  11  day_of_week     float64
#  12  hour            float64
#  13  perc_available  float64
#  14  ctx-4           float64
#  15  ctx-3           float64
#  16  ctx-2           float64
#  17  ctx-1           float64
# dtypes: float64(13), int64(2), object(3)
# memory usage: 428.0+ MB

# %%
#replace column name with name used in kaggle
df_final.rename(columns={"perc_available": "percentage_docks_available"}, inplace=True)

# %%
df_final.head()
# Out:
#    station_id        lat       lon  altitude                        address  \
# 0           1  41.397978  2.180107      16.0  GRAN VIA CORTS CATALANES, 760
# 1           1  41.397978  2.180107      16.0  GRAN VIA CORTS CATALANES, 760
# 2           1  41.397978  2.180107      16.0  GRAN VIA CORTS CATALANES, 760
# 3           1  41.397978  2.180107      16.0  GRAN VIA CORTS CATALANES, 760
# 4           1  41.397978  2.180107      16.0  GRAN VIA CORTS CATALANES, 760
#
#   post_code  capacity        date    year  month  day  day_of_week  hour  \
# 0     08013        46  2022-01-01  2022.0    1.0  1.0          5.0   4.0
# 1     08013        46  2022-01-01  2022.0    1.0  1.0          5.0   9.0
# 2     08013        46  2022-01-01  2022.0    1.0  1.0          5.0  14.0
# 3     08013        46  2022-01-01  2022.0    1.0  1.0          5.0  19.0
# 4     08013        46  2022-01-02  2022.0    1.0  2.0          6.0   0.0
#
#    percentage_docks_available  ctx-4  ctx-3  ctx-2  ctx-1
# 0                        0.72   0.68   0.73   0.74   0.72
# 1                        0.58   0.67   0.63   0.62   0.61
# 2                        0.75   0.62   0.67   0.74   0.75
# 3                        0.65   0.76   0.72   0.69   0.68
# 4                        0.59   0.66   0.68   0.66   0.59

# %%
#convert numbers in these columns to integers
cols_to_int = ['year', 'month', 'day', 'day_of_week', 'hour']
df_final[cols_to_int] = df_final[cols_to_int].astype(int)

# %%
df_final.head()
# Out:
#    station_id        lat       lon  altitude                        address  \
# 0           1  41.397978  2.180107      16.0  GRAN VIA CORTS CATALANES, 760
# 1           1  41.397978  2.180107      16.0  GRAN VIA CORTS CATALANES, 760
# 2           1  41.397978  2.180107      16.0  GRAN VIA CORTS CATALANES, 760
# 3           1  41.397978  2.180107      16.0  GRAN VIA CORTS CATALANES, 760
# 4           1  41.397978  2.180107      16.0  GRAN VIA CORTS CATALANES, 760
#
#   post_code  capacity        date  year  month  day  day_of_week  hour  \
# 0     08013        46  2022-01-01  2022      1    1            5     4
# 1     08013        46  2022-01-01  2022      1    1            5     9
# 2     08013        46  2022-01-01  2022      1    1            5    14
# 3     08013        46  2022-01-01  2022      1    1            5    19
# 4     08013        46  2022-01-02  2022      1    2            6     0
#
#    percentage_docks_available  ctx-4  ctx-3  ctx-2  ctx-1
# 0                        0.72   0.68   0.73   0.74   0.72
# 1                        0.58   0.67   0.63   0.62   0.61
# 2                        0.75   0.62   0.67   0.74   0.75
# 3                        0.65   0.76   0.72   0.69   0.68
# 4                        0.59   0.66   0.68   0.66   0.59

# %%
df_final.describe()
# Out:
#          station_id           lat           lon      altitude      capacity  \
# count  2.952330e+06  2.952330e+06  2.952330e+06  2.952330e+06  2.952330e+06
# mean   2.503873e+02  4.139899e+01  2.168458e+00  3.385821e+01  2.694205e+01
# std    1.447695e+02  2.051463e-02  2.447413e-02  3.113885e+01  6.381171e+00
# min    1.000000e+00  4.134677e+01  2.109154e+00  2.000000e+00  1.200000e+01
# 25%    1.260000e+02  4.138360e+01  2.149207e+00  8.000000e+00  2.400000e+01
# 50%    2.500000e+02  4.139539e+01  2.170939e+00  2.400000e+01  2.700000e+01
# 75%    3.700000e+02  4.141084e+01  2.187440e+00  4.900000e+01  2.900000e+01
# max    5.190000e+02  4.146209e+01  2.220691e+00  1.660000e+02  5.400000e+01
#
#                year         month           day   day_of_week          hour  \
# count  2.952330e+06  2.952330e+06  2.952330e+06  2.952330e+06  2.952330e+06
# mean   2.020713e+03  6.913642e+00  1.573921e+01  2.997791e+00  1.149883e+01
# std    1.069509e+00  3.352681e+00  8.793183e+00  1.999581e+00  6.909640e+00
# min    2.019000e+03  1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.020000e+03  4.000000e+00  8.000000e+00  1.000000e+00  6.000000e+00
# 50%    2.021000e+03  7.000000e+00  1.600000e+01  3.000000e+00  1.200000e+01
# 75%    2.022000e+03  1.000000e+01  2.300000e+01  5.000000e+00  1.700000e+01
# max    2.022000e+03  1.200000e+01  3.100000e+01  6.000000e+00  2.300000e+01
#
#        percentage_docks_available         ctx-4         ctx-3         ctx-2  \
# count                2.952330e+06  2.952330e+06  2.952330e+06  2.952330e+06
# mean                 5.770943e-01  5.770581e-01  5.770974e-01  5.770724e-01
# std                  2.858142e-01  2.857980e-01  2.858141e-01  2.857909e-01
# min                  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%                  3.600000e-01  3.600000e-01  3.600000e-01  3.600000e-01
# 50%                  6.200000e-01  6.200000e-01  6.200000e-01  6.200000e-01
# 75%                  8.200000e-01  8.200000e-01  8.200000e-01  8.200000e-01
# max                  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#               ctx-1
# count  2.952330e+06
# mean   5.770298e-01
# std    2.857951e-01
# min    0.000000e+00
# 25%    3.600000e-01
# 50%    6.200000e-01
# 75%    8.200000e-01
# max    1.000000e+00

# %% [markdown]
# ___
# ## Data from Kaggle:
# To predict the test set and generate the submission file

# %%
kaggle_set_csv = pd.read_csv('/content/drive/MyDrive/CapstoneProject_NathyDani/metadata_sample_submission.csv', encoding = 'unicode_escape', index_col=0)

# %%
kaggle_set_csv.head()
# Out:
#        station_id  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1
# index
# 0             394      3    7     8  0.753086  0.780864  0.799383  0.824074
# 1             337      3   23    12  0.463768  0.536232  0.532609  0.601449
# 2             368      3   31     1  0.787037  0.709877  0.611111  0.601852
# 3             327      3   23    15  0.753472  0.809028  0.819444  0.736111
# 4             328      3    4    20  0.861111  0.802469  0.814815  0.827160

# %%
print(kaggle_set_csv['station_id'].nunique())
print(df_final['station_id'].nunique())
print(df_station_reduced['station_id'].nunique())
# Out:
# 388
# 506
# 506

# %%
# completing with stations info
kaggle_set = pd.merge(kaggle_set_csv, df_station_reduced, on='station_id', how='left')

# %%
print(kaggle_set['station_id'].nunique())
# Out:
# 388

# %%
kaggle_set
# Out:
#        station_id  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# 0             394      3    7     8  0.753086  0.780864  0.799383  0.824074
# 1             337      3   23    12  0.463768  0.536232  0.532609  0.601449
# 2             368      3   31     1  0.787037  0.709877  0.611111  0.601852
# 3             327      3   23    15  0.753472  0.809028  0.819444  0.736111
# 4             328      3    4    20  0.861111  0.802469  0.814815  0.827160
# ...           ...    ...  ...   ...       ...       ...       ...       ...
# 54994         269      3   14     3  0.478261  0.478261  0.478261  0.478261
# 54995         280      3    1     5  0.098765  0.074074  0.074074  0.077160
# 54996         180      3   20    16  0.782680  0.821895  0.812092  0.777778
# 54997         277      3   14    11  0.774691  0.953704  0.972222  0.472222
# 54998         425      3   30    16  0.291667  0.277778  0.204861  0.788194
#
#              lat       lon  altitude  \
# 0      41.387306  2.163126      25.0
# 1      41.398624  2.120494     117.0
# 2      41.396839  2.175660      21.0
# 3      41.405007  2.134603     114.0
# 4      41.402988  2.134469     106.0
# ...          ...       ...       ...
# 54994  41.448152  2.192940      26.0
# 54995  41.413866  2.177727      49.0
# 54996  41.367557  2.138822      14.0
# 54997  41.408211  2.168996      60.0
# 54998  41.376562  2.174862       5.0
#
#                                         address post_code  capacity
# 0                             C/ DIPUTACIÓ, 226     08007      26.0
# 1                          C/ CARME KARR, 12-14     08034      23.0
# 2                             C/ DIPUTACIÓ, 373     08013      27.0
# 3                                   C/ REUS, 23     08022      24.0
# 4                         C/ ARTESA DE SEGRE, 2     08022      26.0
# ...                                         ...       ...       ...
# 54994                          VIA BARCINO, 121     08033      23.0
# 54995         C/ SANT ANTONI Mª CLARET, 290-296     08041      27.0
# 54996  GRAN VIA DE LES CORTS CATALANES, 179 (D)     08014      51.0
# 54997                 TRAVESSERA DE GRÀCIA, 328     08025      27.0
# 54998                         C/ DE CERVELLÓ, 5     08001      24.0
#
# [54999 rows x 14 columns]

# %%
# checking the months that we are going to predict
kaggle_set['month'].unique()
# Out:
# array([3])

# %%
# adapting the dataframe from Kaggle to the model format:
year = 2023
kaggle_set['year'] = year #create 2023 column
kaggle_set['date'] = pd.to_datetime(kaggle_set[['year', 'month', 'day']]) #create date column
kaggle_set['day_of_week'] = pd.DatetimeIndex(kaggle_set['date']).dayofweek #extract day of week

# %%
kaggle_set.head()
# Out:
#    station_id  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# 0         394      3    7     8  0.753086  0.780864  0.799383  0.824074
# 1         337      3   23    12  0.463768  0.536232  0.532609  0.601449
# 2         368      3   31     1  0.787037  0.709877  0.611111  0.601852
# 3         327      3   23    15  0.753472  0.809028  0.819444  0.736111
# 4         328      3    4    20  0.861111  0.802469  0.814815  0.827160
#
#          lat       lon  altitude                address post_code  capacity  \
# 0  41.387306  2.163126      25.0      C/ DIPUTACIÓ, 226     08007      26.0
# 1  41.398624  2.120494     117.0   C/ CARME KARR, 12-14     08034      23.0
# 2  41.396839  2.175660      21.0      C/ DIPUTACIÓ, 373     08013      27.0
# 3  41.405007  2.134603     114.0            C/ REUS, 23     08022      24.0
# 4  41.402988  2.134469     106.0  C/ ARTESA DE SEGRE, 2     08022      26.0
#
#    year       date  day_of_week
# 0  2023 2023-03-07            1
# 1  2023 2023-03-23            3
# 2  2023 2023-03-31            4
# 3  2023 2023-03-23            3
# 4  2023 2023-03-04            5

# %%
#deleting unused columns
kaggle_set = kaggle_set.drop(columns=['date', 'address', 'post_code', 'capacity'])

# %%
#we have some missing values in the lat, lon and altitude columns
#it means that some station is without data
kaggle_set.describe()
# Out:
#          station_id    month           day          hour         ctx-4  \
# count  54999.000000  54999.0  54999.000000  54999.000000  54999.000000
# mean     216.161639      3.0     15.517009     11.533682      0.571921
# std      124.601964      0.0      8.867172      6.878081      0.269534
# min        1.000000      3.0      1.000000      0.000000      0.000000
# 25%      110.000000      3.0      8.000000      6.000000      0.370370
# 50%      217.000000      3.0     15.000000     12.000000      0.604167
# 75%      322.000000      3.0     23.000000     17.000000      0.801282
# max      496.000000      3.0     31.000000     23.000000      1.000000
#
#               ctx-3         ctx-2         ctx-1           lat           lon  \
# count  54999.000000  54999.000000  54999.000000  54714.000000  54714.000000
# mean       0.571794      0.571857      0.571432     41.396759      2.169564
# std        0.269224      0.269640      0.269843      0.018401      0.024450
# min        0.000000      0.000000      0.000000     41.357067      2.111541
# 25%        0.370370      0.370370      0.370370     41.383475      2.151315
# 50%        0.604938      0.604938      0.604938     41.393582      2.173501
# 75%        0.800000      0.800000      0.800000     41.406453      2.188449
# max        1.000000      1.000000      1.000000     41.450608      2.220691
#
#            altitude     year   day_of_week
# count  54714.000000  54999.0  54999.000000
# mean      29.139178   2023.0      2.914871
# std       26.485270      0.0      1.856078
# min        2.000000   2023.0      0.000000
# 25%        7.000000   2023.0      1.000000
# 50%       21.000000   2023.0      3.000000
# 75%       41.000000   2023.0      4.000000
# max      121.000000   2023.0      6.000000

# %%
# #check which station we have missing data
# kaggle_set[kaggle_set['altitude'].isna()]['station_id'].unique()

# %%
kaggle_set[kaggle_set['station_id'] == 94].head()
# Out:
#       station_id  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# 8             94      3    8    17  0.871528  0.855903  0.786458  0.822917
# 1990          94      3    9    13  0.463542  0.484375  0.510417  0.631944
# 2054          94      3   19     8  0.564236  0.583333  0.534722  0.055556
# 2703          94      3   29     5  0.916667  0.866319  0.437500  0.375000
# 3422          94      3   13    22  0.614583  0.626736  0.751736  0.826389
#
#       lat  lon  altitude  year  day_of_week
# 8     NaN  NaN       NaN  2023            2
# 1990  NaN  NaN       NaN  2023            3
# 2054  NaN  NaN       NaN  2023            6
# 2703  NaN  NaN       NaN  2023            2
# 3422  NaN  NaN       NaN  2023            0

# %%
# we will check the information for station 94 in the March data
df_station_march = pd.read_csv('/content/drive/My Drive/CapstoneProject_NathyDani/2023_03_Marc_BicingNou_INFORMACIO.csv')

# %%
df_station_march[df_station_march['station_id'] == 94].head(1)
# Out:
#     station_id                                 name physical_configuration  \
# 88          94  GRAN VIA DE LES CORTS CATALANES,375    ELECTRICBIKESTATION
#
#           lat      lon  altitude                                    address  \
# 88  41.375791  2.14991        26  GRAN  VIA DE LES CORTS CATALANES, 375-385
#
#     post_code  capacity  is_charging_station  nearby_distance  \
# 88       8015        48                 True             1000
#
#     x_ride_code_support cross_street  last_updated  ttl  rental_uris
# 88                 True          NaN    1677625200   26          NaN

# %%
#complete the station 94 information
kaggle_set.loc[kaggle_set['station_id']==94, ['lat']] = 41.375791
kaggle_set.loc[kaggle_set['station_id']==94, ['lon']] = 2.14991
kaggle_set.loc[kaggle_set['station_id']==94, ['altitude']] = 26

# %%
#checking
kaggle_set[kaggle_set['station_id'] == 94].head()
# Out:
#       station_id  month  day  hour     ctx-4     ctx-3     ctx-2     ctx-1  \
# 8             94      3    8    17  0.871528  0.855903  0.786458  0.822917
# 1990          94      3    9    13  0.463542  0.484375  0.510417  0.631944
# 2054          94      3   19     8  0.564236  0.583333  0.534722  0.055556
# 2703          94      3   29     5  0.916667  0.866319  0.437500  0.375000
# 3422          94      3   13    22  0.614583  0.626736  0.751736  0.826389
#
#             lat      lon  altitude  year  day_of_week
# 8     41.375791  2.14991      26.0  2023            2
# 1990  41.375791  2.14991      26.0  2023            3
# 2054  41.375791  2.14991      26.0  2023            6
# 2703  41.375791  2.14991      26.0  2023            2
# 3422  41.375791  2.14991      26.0  2023            0

# %%
kaggle_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54999 entries, 0 to 54998
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   station_id   54999 non-null  int64
#  1   month        54999 non-null  int64
#  2   day          54999 non-null  int64
#  3   hour         54999 non-null  int64
#  4   ctx-4        54999 non-null  float64
#  5   ctx-3        54999 non-null  float64
#  6   ctx-2        54999 non-null  float64
#  7   ctx-1        54999 non-null  float64
#  8   lat          54857 non-null  float64
#  9   lon          54857 non-null  float64
#  10  altitude     54857 non-null  float64
#  11  year         54999 non-null  int64
#  12  day_of_week  54999 non-null  int64
# dtypes: float64(7), int64(6)
# memory usage: 5.9 MB

# %%
#checking
kaggle_set.describe()
# Out:
#          station_id    month           day          hour         ctx-4  \
# count  54999.000000  54999.0  54999.000000  54999.000000  54999.000000
# mean     216.161639      3.0     15.517009     11.533682      0.571921
# std      124.601964      0.0      8.867172      6.878081      0.269534
# min        1.000000      3.0      1.000000      0.000000      0.000000
# 25%      110.000000      3.0      8.000000      6.000000      0.370370
# 50%      217.000000      3.0     15.000000     12.000000      0.604167
# 75%      322.000000      3.0     23.000000     17.000000      0.801282
# max      496.000000      3.0     31.000000     23.000000      1.000000
#
#               ctx-3         ctx-2         ctx-1           lat           lon  \
# count  54999.000000  54999.000000  54999.000000  54857.000000  54857.000000
# mean       0.571794      0.571857      0.571432     41.396704      2.169513
# std        0.269224      0.269640      0.269843      0.018408      0.024439
# min        0.000000      0.000000      0.000000     41.357067      2.111541
# 25%        0.370370      0.370370      0.370370     41.383365      2.151038
# 50%        0.604938      0.604938      0.604938     41.393535      2.173002
# 75%        0.800000      0.800000      0.800000     41.406453      2.188449
# max        1.000000      1.000000      1.000000     41.450608      2.220691
#
#            altitude     year   day_of_week
# count  54857.000000  54999.0  54999.000000
# mean      29.130995   2023.0      2.914871
# std       26.451210      0.0      1.856078
# min        2.000000   2023.0      0.000000
# 25%        7.000000   2023.0      1.000000
# 50%       22.000000   2023.0      3.000000
# 75%       41.000000   2023.0      4.000000
# max      121.000000   2023.0      6.000000

# %% [markdown]
# ##Save data frames to be accessed outside this notebook

# %%
#saving df_final.csv
path = '/content/drive/My Drive/CapstoneProject_NathyDani/df_final.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_final.to_csv(f, index=False)

# %%
#saving df_stations.csv
path = '/content/drive/My Drive/CapstoneProject_NathyDani/df_stations.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_station_reduced.to_csv(f, index=False)

# %%
#saving kaggle_set.csv
path = '/content/drive/My Drive/CapstoneProject_NathyDani/kaggle_set.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  kaggle_set.to_csv(f, index=False)
